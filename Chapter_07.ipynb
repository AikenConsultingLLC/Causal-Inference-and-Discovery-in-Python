# %%
# %pip install --upgrade jupyter ipywidgets
# Out:
# Requirement already satisfied: jupyter in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: ipywidgets in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (8.1.8)
# Requirement already satisfied: notebook in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter) (7.5.3)
# Requirement already satisfied: jupyter-console in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter) (7.1.0)
# Requirement already satisfied: jupyterlab in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter) (4.5.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipywidgets) (9.8.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator>=4.3.2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: wcwidth in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: appnope>=0.1.2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipykernel->jupyter) (1.8.19)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipykernel->jupyter) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipykernel->jupyter) (27.0.2)
# Requirement already satisfied: tornado>=6.2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from ipykernel->jupyter) (6.5.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.5.1)
# Requirement already satisfied: six>=1.5 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab->jupyter) (79.0.1)
# Requirement already satisfied: anyio in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.10.0)
# Requirement already satisfied: certifi in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from nbconvert->jupyter) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from nbconvert->jupyter) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from nbconvert->jupyter) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2025.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install dowhy
# Out:
# Requirement already satisfied: dowhy in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (0.14)
# Requirement already satisfied: causal-learn>=0.1.3.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (0.1.4.4)
# Requirement already satisfied: cvxpy<2.0.0,>=1.7.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (1.8.0)
# Requirement already satisfied: cython>=3.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (3.2.4)
# Requirement already satisfied: joblib>=1.1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (1.5.2)
# Requirement already satisfied: networkx>=3.3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (3.5)
# Requirement already satisfied: numba>=0.59 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (0.63.1)
# Requirement already satisfied: numpy>2.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (2.3.5)
# Requirement already satisfied: pandas>1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (2.2.2)
# Requirement already satisfied: scikit-learn>1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (1.6.1)
# Requirement already satisfied: scipy<=1.15.3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (1.15.3)
# Requirement already satisfied: statsmodels>=0.14 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (0.14.6)
# Requirement already satisfied: sympy>=1.10.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (1.14.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from dowhy) (4.67.1)
# Requirement already satisfied: osqp>=1.0.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (1.1.0)
# Requirement already satisfied: clarabel>=0.5.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (3.2.11)
# Requirement already satisfied: highspy>=1.11.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (1.12.0)
# Requirement already satisfied: graphviz in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from causal-learn>=0.1.3.0->dowhy) (0.21)
# Requirement already satisfied: matplotlib in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from causal-learn>=0.1.3.0->dowhy) (3.10.8)
# Requirement already satisfied: pydot in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from causal-learn>=0.1.3.0->dowhy) (4.0.1)
# Requirement already satisfied: momentchi2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from causal-learn>=0.1.3.0->dowhy) (0.1.8)
# Requirement already satisfied: cffi in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from clarabel>=0.5.0->cvxpy<2.0.0,>=1.7.1->dowhy) (1.17.1)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from numba>=0.59->dowhy) (0.46.0)
# Requirement already satisfied: jinja2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (3.1.6)
# Requirement already satisfied: setuptools in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (79.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pandas>1.0->dowhy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pandas>1.0->dowhy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pandas>1.0->dowhy) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>1.0->dowhy) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from scikit-learn>1.0->dowhy) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from statsmodels>=0.14->dowhy) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from statsmodels>=0.14->dowhy) (25.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sympy>=1.10.1->dowhy) (1.3.0)
# Requirement already satisfied: pycparser in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from cffi->clarabel>=0.5.0->cvxpy<2.0.0,>=1.7.1->dowhy) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jinja2->osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (3.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from scipy import stats

import dowhy
from dowhy import CausalModel

from sklearn.linear_model import LassoCV
from sklearn.ensemble import GradientBoostingRegressor

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import graphviz

# %%
dowhy.__version__
# Out:
# '0.14'

# %%
COLORS = [
    '#00B0F0',
    '#FF0000'
]

# %% [markdown]
# # Chapter 07
#
# In this chapter we focus on the full four-steps causal inference process. First, we introduce DoWhy and EconML libraries. Next, we discuss and exercise how to encode causal information in a form of a graph that is understandable to DoWhy. Next, we demonstrate how to find applicable estimands for a problem at hand. Then, we compute causal effect estimates using DoWhy and estimators provided in EconML. To understand how good our estimates are, we perform a series of refutal tests. Finally, we run a full (and more complex) causal process using DoWhy and EconML.

# %% [markdown]
# ## Causal models with DoWhy & EconML

# %% [markdown]
# ### Generate the data

# %%
# First, we'll build a structural causal model (SCM)
class GPSMemorySCM:
    
    def __init__(self, random_seed=None):
        self.random_seed = random_seed
        self.u_x = stats.truncnorm(0, np.inf, scale=5)
        self.u_y = stats.norm(scale=2)
        self.u_z = stats.norm(scale=2)
        self.u = stats.truncnorm(0, np.inf, scale=4)
        
    def sample(self, sample_size=100, treatment_value=None):
        """Samples from the SCM"""
        if self.random_seed:
            np.random.seed(self.random_seed)
        
        u_x = self.u_x.rvs(sample_size)
        u_y = self.u_y.rvs(sample_size)
        u_z = self.u_z.rvs(sample_size)
        u = self.u.rvs(sample_size)
        
        if treatment_value:
            gps = np.array([treatment_value]*sample_size)
        else:
            gps = u_x + 0.7*u
            
        hippocampus = -0.6*gps + 0.25*u_z
        memory = 0.7*hippocampus + 0.25*u
        
        return gps, hippocampus, memory
    
    def intervene(self, treatment_value, sample_size=100):
        """Intervenes on the SCM"""
        return self.sample(treatment_value=treatment_value, sample_size=sample_size)

# %%
# Instantiate the SCM
scm = GPSMemorySCM()

# Generate observational data
gps_obs, hippocampus_obs, memory_obs = scm.sample(1000)

# Encode as a pandas df
df = pd.DataFrame(np.vstack([gps_obs, hippocampus_obs, memory_obs]).T, columns=['X', 'Z', 'Y'])

# %%
df
# Out:
#             X         Z         Y
# 0    4.897070 -2.467533 -1.279758
# 1    4.462135 -2.177485 -1.096029
# 2    1.653712 -1.953711 -1.341881
# 3    9.672615 -5.434128 -1.058025
# 4    3.754297 -2.308652 -1.106659
# ..        ...       ...       ...
# 995  3.029629 -1.808266 -1.016481
# 996  2.945228 -1.520756 -1.018646
# 997  6.722807 -4.726489 -2.446996
# 998  4.281119 -3.219886 -0.837942
# 999  2.690002 -1.323820 -0.096891
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Step 1: Modeling the problem

# %% [markdown]
# #### Step 1.1 - Define the graph - `GML`

# %%
# Create the graph describing the causal structure
gml_graph = """
graph [
    directed 1
    
    node [
        id "X" 
        label "X"
    ]    
    node [
        id "Z"
        label "Z"
    ]
    node [
        id "Y"
        label "Y"
    ]
    node [
        id "U"
        label "U"
    ]
    
    edge [
        source "X"
        target "Z"
    ]
    edge [
        source "Z"
        target "Y"
    ]
    edge [
        source "U"
        target "X"
    ]
    edge [
        source "U"
        target "Y"
    ]
]
"""

# %% [markdown]
# #### Step 1.2 - define the DoWhy model

# %%
# With graph
model = CausalModel(
    data=df,
    treatment='X',
    outcome='Y',
    graph=gml_graph
)
# Out:
# /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages/dowhy/causal_model.py:581: UserWarning: 1 variables are assumed unobserved because they are not in the dataset. Configure the logging level to `logging.WARNING` or higher for additional details.
#   warnings.warn(

# %%
model.view_model()

# %% [markdown]
# ### Step 2: Identify the estimand

# %%
estimand = model.identify_effect()
print(estimand)
# Out:
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# No such variable(s) found!
#
# ### Estimand : 2
# Estimand name: iv
# No such variable(s) found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# Estimand expression:
#  ⎡ d       d       ⎤
# E⎢────(Y)⋅────([Z])⎥
#  ⎣d[Z]    d[X]     ⎦
# Estimand assumption 1, Full-mediation: Z intercepts (blocks) all directed paths from X to Y.
# Estimand assumption 2, First-stage-unconfoundedness: If U→{X} and U→{Z} then P(Z|X,U) = P(Z|X)
# Estimand assumption 3, Second-stage-unconfoundedness: If U→{Z} and U→Y then P(Y|Z, X, U) = P(Y|Z, X)
#
# ### Estimand : 4
# Estimand name: general_adjustment
# No such variable(s) found!

# %% [markdown]
# ### Step 3: Estimate the causal effect

# %% [markdown]
# #### Example 1 - Linear Regression

# %%
estimate = model.estimate_effect(
    identified_estimand=estimand,
    method_name='frontdoor.two_stage_regression')

print(f'Estimate of causal effect (linear regression): {estimate.value}')
# Out:
# Estimate of causal effect (linear regression): -0.4166730231657858

# %% [markdown]
# ### Step 4: Run refutation tests

# %%
refute_subset = model.refute_estimate(
    estimand=estimand, 
    estimate=estimate,
    method_name="data_subset_refuter", 
    subset_fraction=0.4)

# %%
print(refute_subset)
# Out:
# Refute: Use a subset of data
# Estimated effect:-0.4166730231657858
# New effect:-0.41401158218620815
# p value:0.94

# %% [markdown]
# ## Full example

# %% [markdown]
# ### Data

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['S', 'Q', 'X', 'Y', 'P']
positions = ['2,2.5!', '3,1!', '3,0!', '1, 0!', '1,2!', '1.7,0.9!']

edges = ['SQ', 'SY', 'QX', 'QY', 'XP', 'YP', 'XY']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_07_full_example')

graph

# %%
SAMPLE_SIZE = 1000

S = np.random.random(SAMPLE_SIZE)
Q = 0.2*S + 0.67*np.random.random(SAMPLE_SIZE)
X = 0.14*Q + 0.4*np.random.random(SAMPLE_SIZE)
Y = 0.7*X + 0.11*Q + 0.32*S + 0.24*np.random.random(SAMPLE_SIZE)
P = 0.43*X + 0.21*Y + 0.22*np.random.random(SAMPLE_SIZE)

# Encode as a pandas df
df = pd.DataFrame(np.vstack([S, Q, X, Y, P]).T, columns=['S', 'Q', 'X', 'Y', 'P'])

# %%
# Generate the GML graph
gml_string = 'graph [directed 1\n'

for node in nodes:
    gml_string += f'\tnode [id "{node}" label "{node}"]\n'

for edge in edges:
    gml_string += f'\tedge [source "{edge[0]}" target "{edge[1]}"]\n'
    
gml_string += ']'

# %%
print(gml_string)
# Out:
# graph [directed 1
# 	node [id "S" label "S"]
# 	node [id "Q" label "Q"]
# 	node [id "X" label "X"]
# 	node [id "Y" label "Y"]
# 	node [id "P" label "P"]
# 	edge [source "S" target "Q"]
# 	edge [source "S" target "Y"]
# 	edge [source "Q" target "X"]
# 	edge [source "Q" target "Y"]
# 	edge [source "X" target "P"]
# 	edge [source "Y" target "P"]
# 	edge [source "X" target "Y"]
# ]

# %%
# Instantiate the CausalModel 
model = CausalModel(
    data=df,
    treatment='X',
    outcome='Y',
    graph=gml_string
)

# %%
# %pip install econml
# Out:
# Requirement already satisfied: econml in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (0.16.0)
# Requirement already satisfied: numpy in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (2.3.5)
# Requirement already satisfied: scipy>1.4.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (1.15.3)
# Requirement already satisfied: scikit-learn<1.7,>=1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (1.6.1)
# Requirement already satisfied: sparse in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (0.17.0)
# Requirement already satisfied: joblib>=0.13.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (1.5.2)
# Requirement already satisfied: statsmodels>=0.10 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (0.14.6)
# Requirement already satisfied: pandas>1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (2.2.2)
# Requirement already satisfied: shap<0.49.0,>=0.38.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (0.48.0)
# Requirement already satisfied: lightgbm in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (4.6.0)
# Requirement already satisfied: packaging in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from econml) (25.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from scikit-learn<1.7,>=1.0->econml) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from shap<0.49.0,>=0.38.1->econml) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from shap<0.49.0,>=0.38.1->econml) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from shap<0.49.0,>=0.38.1->econml) (0.63.1)
# Requirement already satisfied: cloudpickle in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from shap<0.49.0,>=0.38.1->econml) (3.1.1)
# Requirement already satisfied: typing-extensions in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from shap<0.49.0,>=0.38.1->econml) (4.15.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from numba>=0.54->shap<0.49.0,>=0.38.1->econml) (0.46.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pandas>1.0->econml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pandas>1.0->econml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pandas>1.0->econml) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>1.0->econml) (1.17.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/oneshin/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from statsmodels>=0.10->econml) (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
model.view_model()

# %%
# Get the estimand
estimand = model.identify_effect()
print(estimand)
# Out:
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#  d
# ────(E[Y|Q])
# d[X]
# Estimand assumption 1, Unconfoundedness: If U→{X} and U→Y then P(Y|X,Q,U) = P(Y|X,Q)
#
# ### Estimand : 2
# Estimand name: iv
# No such variable(s) found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# No such variable(s) found!
#
# ### Estimand : 4
# Estimand name: general_adjustment
# Estimand expression:
#  d
# ────(E[Y|Q])
# d[X]
# Estimand assumption 1, Unconfoundedness: If U→{X} and U→Y then P(Y|X,Q,U) = P(Y|X,Q)

# %%
import warnings
from sklearn.exceptions import DataConversionWarning

warnings.filterwarnings(action='ignore', category=DataConversionWarning)

# %%
estimate = model.estimate_effect(
    identified_estimand=estimand,
    method_name='backdoor.econml.dml.DML',
    method_params={
        'init_params': {
            'model_y': GradientBoostingRegressor(),
            'model_t': GradientBoostingRegressor(),
            'model_final': LassoCV(fit_intercept=False),
        },
        'fit_params': {}}
)

print(f'Estimate of causal effect (DML): {estimate.value}')
# Out:
# Estimate of causal effect (DML): 0.6813022449221876

# %%
estimate_lr = model.estimate_effect(
    identified_estimand=estimand,
    method_name='backdoor.linear_regression')

print(f'Estimate of causal effect (linear regression): {estimate_lr.value}')
# Out:
# Estimate of causal effect (linear regression): 0.709066615248138

# %%
random_cause = model.refute_estimate(
    estimand=estimand, 
    estimate=estimate,
    method_name='random_common_cause'
)

# %%
print(random_cause)
# Out:
# Refute: Add a random common cause
# Estimated effect:0.6813022449221876
# New effect:0.6745361172277136
# p value:0.66

# %%
# Ignore specific statsmodels warnings
from statsmodels.tools.sm_exceptions import ValueWarning
warnings.filterwarnings("ignore")

# 1. Estimate the effect using a simple method (like Linear Regression)
estimate = model.estimate_effect(
    identified_estimand=estimand,
    method_name="backdoor.linear_regression"
)

# 2. Run the simple refutation
refutation = model.refute_estimate(
    estimand=estimand,
    estimate=estimate,
    method_name="placebo_treatment_refuter"
)

print(refutation)
# Out:
# Refute: Use a Placebo Treatment
# Estimated effect:0.709066615248138
# New effect:0.0
# p value:1.0

# %%
# From Book 

#placebo_refuter = model.refute_estimate(
#    estimand=estimand, 
#    estimate=estimate,
#    method_name='placebo_treatment_refuter'
#)

# %%
#print(placebo_refuter)

# %% [markdown]
# ## GCM API

# %%
import networkx as nx
from dowhy import gcm

# %%
SAMPLE_SIZE = 1000

S = np.random.random(SAMPLE_SIZE)
Q = 0.2*S + 0.67*np.random.random(SAMPLE_SIZE)
X = 0.14*Q + 0.4*np.random.random(SAMPLE_SIZE)
Y = 0.7*X + 0.11*Q + 0.32*S + 0.24*np.random.random(SAMPLE_SIZE)
P = 0.43*X + 0.21*Y + 0.22*np.random.random(SAMPLE_SIZE)

# Encode as a pandas df
df = pd.DataFrame(np.vstack([S, Q, X, Y, P]).T, columns=['S', 'Q', 'X', 'Y', 'P'])

# %%
edges = ['SQ', 'SY', 'QX', 'QY', 'XP', 'YP', 'XY']
graph_nx = nx.DiGraph([(edge[0], edge[1]) for edge in edges])

# %%
nx.draw(
    graph_nx, 
    with_labels=True, 
    node_size=900,
    font_color='white', 
    node_color=COLORS[0]
)

# %%
causal_model = gcm.InvertibleStructuralCausalModel(graph_nx)

# %%
causal_model.set_causal_mechanism('S', gcm.EmpiricalDistribution())
causal_model.set_causal_mechanism('X', gcm.AdditiveNoiseModel(gcm.ml.create_linear_regressor()))
causal_model.set_causal_mechanism('Y', gcm.AdditiveNoiseModel(gcm.ml.create_linear_regressor()))
causal_model.set_causal_mechanism('P', gcm.AdditiveNoiseModel(gcm.ml.create_linear_regressor()))
causal_model.set_causal_mechanism('Q', gcm.AdditiveNoiseModel(gcm.ml.create_linear_regressor()))

gcm.fit(causal_model, df)
# Out:
# Fitting causal mechanism of node P: 100%|███████████████████████████████████████████████████████| 5/5 [00:00<00:00, 176.58it/s]

# %%
gcm.arrow_strength(causal_model, 'Y')
# Out:
# {('Q', 'Y'): np.float64(0.00040101431272765274),
#  ('S', 'Y'): np.float64(0.009286638043810264),
#  ('X', 'Y'): np.float64(0.007201687853568534)}

# %%
gcm.counterfactual_samples(
    causal_model,
    {'X': lambda x: .21},
    observed_data=pd.DataFrame(data=dict(X=[.5], Y=[.75], S=[.5], Q=[.4], P=[.34])))
# Out:
#      S    Q     X         Y         P
# 0  0.5  0.4  0.21  0.545357  0.172479
